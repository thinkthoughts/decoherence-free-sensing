# %% [markdown]
# # 29 Collective Emission
#
# Dissipative collective-emission preparation.
#
# Paper: *Lieb-Mattis States for Robust Entangled Differential Phase Sensing*.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from dfs_sensing.core import *

# %% [markdown]
# ## Next step
#
# Replace this scaffold with the first executable specification for this notebook.
